# %% [markdown]
# # AWS Marketplace Product Usage Demonstration - 7Park Data Drug NER

# %% [markdown]
# **7Park Data** drug NER allows you to identify and surface drug (trade) names in unstructured text data such as patient records, customer orders, news and reports, and more.
#
# Use this solution for competitive intelligence, for better customer service, more targeted prospecting and to make more data driven decisions.
#
# Our drug classifier (NER) has been trained and optimized on 200 thousand healthcare articles and blogs from the LexisNexis database and achieves an F1 score of 88% on our data.

# %% [markdown]
# # Pre-requisites

# %% [markdown]
# This sample notebook requires subscription to the following pre-trained machine learning model packages from AWS Marketplace:
#
# **[Drug NER](https://aws.amazon.com/marketplace/pp/prodview-47xyf7s3glruu?qid=1575415914406&sr=0-5&ref_=srh_res_product_title)**
#
# If your AWS account has not been subscribed to these listings, here is the process you can follow for each of the above mentioned listings:
#
# 1. Open the listing from AWS Marketplace
# 1. Read the **Highlights** section and then **product overview** section of the listing.
# 1. View **usage information** and then **additional resources.**
# 1. Note the supported instance types.
# 1. Next, click on **Continue to subscribe.**
# 1. Review **End user license agreement, support terms**, as well as **pricing information.**
# 1. **"Accept Offer"** button needs to be clicked if your organization agrees with EULA, pricing information as well as support terms.
#
# **Notes:**
#
# If **Continue to configuration** button is active, it means your account already has a subscription to this listing.
# Once you click on **Continue to configuration** button and then choose region, you will see that a Product Arn will appear. This is the model package ARN that you need to specify while creating a deployable model. However, for this notebook, the algorithm ARN has been specified in **src/model_package_arns.py** file and you do not need to specify the same explicitly.

# %% [markdown]
# # Set up environment and view a sample image

# %% [markdown]
# In this section, we will import necessary libraries and define variables such as an S3 bucket, an IAM role, and sagemaker session to be used.

# %%
import json
from pprint import pprint
import sagemaker as sage
from sagemaker import get_execution_role
from sagemaker import ModelPackage

from src.model_package_arns import ModelPackageArnProvider

role = get_execution_role()

sagemaker_session = sage.Session()

# %% [markdown]
# # Live Inference Endpoint

# %% [markdown]
# ## Step 1: Deploy the model for performing real-time inference.

# %%
# Get the model_package_arn
modelpackage_arn = ModelPackageArnProvider.get_model_package_arn(sagemaker_session.boto_region_name)

# Define predictor wrapper class
def ner_detection_predict_wrapper(endpoint, session):
    return sage.RealTimePredictor(endpoint, session, content_type='application/json')

# Create a deployable model package
ner_model = ModelPackage(role=role,
                         model_package_arn=modelpackage_arn,
                         sagemaker_session=sagemaker_session,
                         predictor_cls=ner_detection_predict_wrapper)

# Deploy the model
ner_predictor = ner_model.deploy(initial_instance_count=1, 
                                 instance_type='ml.t2.2xlarge',
                                 endpoint_name='drug-ner-endpoint')
# Out:
# ---------------------------------------------------------------------------------------------------------------!

# %% [markdown]
# ## Step 2: Perform a prediction on Amazon Sagemaker Endpoint created.

# %%
sample = {'instance': 
          'Subsequently, eligible patients who have not experienced disease progression '
          'at week 24 will continue in a maintenance phase where a single dose of ipilimumab will be '
          'administered once every 12 weeks until disease progression.'
         }

# Perform a prediction
ner_result = ner_predictor.predict(json.dumps(sample)).decode('utf-8')

# View the prediction
pprint(json.loads(ner_result))
# Out:
# {'ner': [{'end_pos': 158,
#           'key': 'ipilimumab',
#           'start_pos': 148,
#           'type': 'NE_DRUG'}]}

# %% [markdown]
# # Batch Transform Job

# %% [markdown]
# Now let's use the model built to run a batch inference job and verify it works.

# %% [markdown]
# The model supports data in [jsonlines](http://jsonlines.org/) format.

# %%
# review input file
SAMPLE_FILE = 'data/samples.jl'

with open(SAMPLE_FILE) as f:
    print(f.read())
# Out:
# {"id": 0, "instance": "Subsequently, eligible patients who have not experienced disease progression at week 24 will continue in a maintenance phase where a single dose of ipilimumab will be administered once every 12 weeks until disease progression."}
# {"id": 1, "instance": "The investigational new drug （ IND ） application for IBI306 was approved by the National Medical Products Administration (NMPA) in September 2017."}
# {"id": 2, "instance": "In June 2005, UCB announced significant positive results for the two pivotal phase III trials (PRECiSE 1 and 2) of CIMZIATM in the induction and maintenance of clinical response in moderate to severe active Crohn's disease."}
# {"id": 3, "instance": "Carefully weigh the risks and benefits of treatment with OTEZLA for patients with a history of depression and/or suicidal thoughts/behavior, or in patients who develop such symptoms while on OTEZLA."}
# {"id": 4, "instance": "In contrast, pre-clinical data indicate that PRTX-100 may have the potential to treat ITP by reducing the immune-mediated destruction of the platelets through immunomodulatory processes that don ’ t lead to immunosuppression."}

# %% [markdown]
# ## Step 1: Update the input file to S3

# %%
transform_input = sagemaker_session.upload_data(
    SAMPLE_FILE, 
    key_prefix='drug_ner/' + SAMPLE_FILE)
print("Transform input uploaded to " + transform_input)
# Out:
# Transform input uploaded to s3://sagemaker-us-east-1-084888172679/drug_ner/data/samples.jl/samples.jl

# %% [markdown]
# ## Step 2: Run a new transform job

# %%
import json 
import uuid

transformer = ner_model.transformer(1, 'ml.m4.xlarge', 
                                    accept="application/jsonlines",
                                    assemble_with='Line')
transformer.transform(
    transform_input, 
    content_type='application/jsonlines',
    join_source= "Input",
    split_type='Line'
)
transformer.wait()

print("Batch Transform output saved to " + transformer.output_path)
# Out:
# Using already existing model: ner-drugs-2019-11-22-20-00-09--099d95f0-2019-12-04-16-23-23-620
# ................................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2019/12/04 16:39:16 [crit] 21#21: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:16 [crit] 21#21: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:16 [crit] 21#21: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:16 [crit] 21#21: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# Processing /opt/ml/code
# 2019/12/04 16:39:16 [crit] 21#21: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:16 [crit] 21#21: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:16 [crit] 21#21: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Building wheels for collected packages: run
#   Building wheel for run (setup.py): started
# 2019/12/04 16:39:16 [crit] 21#21: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:16 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:17 [crit] 21#21: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:17 [crit] 21#21: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:17 [crit] 21#21: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for run (setup.py): finished with status 'done'
#   Created wheel for run: filename=run-1.0.0-py2.py3-none-any.whl size=62202 sha256=dbd6df573d3cacda489fecadf350b2f56ab23b79c31e529f6650ad509e814f4d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6v7b53s9/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built run
# 2019/12/04 16:39:17 [crit] 21#21: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:17 [crit] 21#21: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:17 [crit] 21#21: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Installing collected packages: run
# 2019/12/04 16:39:17 [crit] 21#21: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Successfully installed run-1.0.0
# 2019/12/04 16:39:17 [crit] 21#21: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:17 [crit] 21#21: *33 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:17 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *35 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *37 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *39 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *41 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *43 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *45 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *47 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *49 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *51 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:18 [crit] 21#21: *53 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:18 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *55 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *57 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *59 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *61 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *63 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *65 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *67 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *69 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *71 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:19 [crit] 21#21: *73 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:19 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *75 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *77 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *79 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *81 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *83 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *85 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *87 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *89 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *91 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:20 [crit] 21#21: *93 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:20 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *95 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *97 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *99 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *101 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *103 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *105 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *107 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *109 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:21 [crit] 21#21: *111 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:21 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *113 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *115 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *117 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *119 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *121 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *123 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *125 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *127 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *129 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:22 [crit] 21#21: *131 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:22 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *133 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *135 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *137 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *139 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *141 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *143 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *145 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *147 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:23 [crit] 21#21: *149 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:23 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *151 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *153 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *155 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *157 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *159 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *161 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *163 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *165 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *167 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:24 [crit] 21#21: *169 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:24 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *171 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *173 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *175 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *177 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *179 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *181 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *183 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *185 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *187 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:25 [crit] 21#21: *189 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:25 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *191 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *193 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *195 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *197 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *199 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *201 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *203 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *205 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:26 [crit] 21#21: *207 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *209 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *211 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *213 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *215 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *217 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *219 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *221 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *223 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *225 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:27 [crit] 21#21: *227 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:28 [crit] 21#21: *229 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:28 [crit] 21#21: *231 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:28 [crit] 21#21: *233 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:28 [crit] 21#21: *235 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:28 [crit] 21#21: *237 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:28 [crit] 21#21: *239 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# ...
# 2019/12/04 16:39:35 [crit] 21#21: *367 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *369 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *371 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *373 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *375 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *377 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *379 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:35 [crit] 21#21: *381 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:35 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *383 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *385 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *387 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *389 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *391 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *393 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *395 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *397 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *399 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:36 [crit] 21#21: *401 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:36 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *403 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *405 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *407 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *409 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *411 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *413 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *415 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *417 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *419 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:37 [crit] 21#21: *421 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:37 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:38 [crit] 21#21: *423 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:38 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:38 [crit] 21#21: *425 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:38 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2019/12/04 16:39:38 [crit] 21#21: *427 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [04/Dec/2019:16:39:38 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2019-12-04 16:39:38 +0000] [36] [INFO] Starting gunicorn 19.9.0
# [2019-12-04 16:39:38 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2019-12-04 16:39:38 +0000] [36] [INFO] Using worker: gevent
# [2019-12-04 16:39:38 +0000] [39] [INFO] Booting worker with pid: 39
# [2019-12-04 16:39:38 +0000] [40] [INFO] Booting worker with pid: 40
# [2019-12-04 16:39:38 +0000] [41] [INFO] Booting worker with pid: 41
# [2019-12-04 16:39:38 +0000] [45] [INFO] Booting worker with pid: 45
# Processing /opt/ml/code
# Building wheels for collected packages: run
#   Building wheel for run (setup.py): started
#   Building wheel for run (setup.py): finished with status 'done'
#   Created wheel for run: filename=run-1.0.0-py2.py3-none-any.whl size=62203 sha256=651a2085fa5b4912d8af5f57fde57cda9685934ba2a189ccd84c11d6583a1971
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g8l8o4c9/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built run
# Installing collected packages: run
#   Found existing installation: run 1.0.0
#     Uninstalling run-1.0.0:
#       Successfully uninstalled run-1.0.0
# Successfully installed run-1.0.0
# Processing /opt/ml/code
# Building wheels for collected packages: run
#   Building wheel for run (setup.py): started
#   Building wheel for run (setup.py): finished with status 'done'
#   Created wheel for run: filename=run-1.0.0-py2.py3-none-any.whl size=62205 sha256=0c1001d1574e51caf7fa8738a9c561202fdcb77a63b31c7afddbf4d35508024c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4t91okyr/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built run
# Installing collected packages: run
#   Found existing installation: run 1.0.0
#     Uninstalling run-1.0.0:
#       Successfully uninstalled run-1.0.0
# Successfully installed run-1.0.0
# 169.254.255.130 - - [04/Dec/2019:16:40:11 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# Processing /opt/ml/code
# Building wheels for collected packages: run
#   Building wheel for run (setup.py): started
#   Building wheel for run (setup.py): finished with status 'done'
#   Created wheel for run: filename=run-1.0.0-py2.py3-none-any.whl size=62201 sha256=391b2129c2625ea10bc1cf3737964ac3aafddc17a33dab5f80576d0303ad88f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w85ndtwp/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built run
# Installing collected packages: run
#   Found existing installation: run 1.0.0
#     Uninstalling run-1.0.0:
#       Successfully uninstalled run-1.0.0
# Successfully installed run-1.0.0
# 169.254.255.130 - - [04/Dec/2019:16:40:40 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
#
# 169.254.255.130 - - [04/Dec/2019:16:41:08 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:41:08 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:41:08 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:41:08 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2019-12-04T16:41:08.700:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [04/Dec/2019:16:41:08 +0000] "POST /invocations HTTP/1.1" 200 484 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:41:08 +0000] "POST /invocations HTTP/1.1" 200 484 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:41:10 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [04/Dec/2019:16:41:10 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# Batch Transform output saved to s3://sagemaker-us-east-1-084888172679/ner-drugs-2019-11-22-20-00-09--099d95f0-2019-12-04-16-34-08-836

# %% [markdown]
# ## Step 3: Inspect the Batch Transform Output in S3

# %%
from urllib.parse import urlparse

parsed_url = urlparse(transformer.output_path)
bucket_name = parsed_url.netloc
file_key = '{}/{}.out'.format(parsed_url.path[1:], "samples.jl")

s3_client = sagemaker_session.boto_session.client('s3')

response = s3_client.get_object(Bucket = sagemaker_session.default_bucket(), Key = file_key)
response_bytes = response['Body'].read().decode('utf-8')

print(response_bytes)
# Out:
# {"SageMakerOutput":{"ner":[{"end_pos":158,"key":"ipilimumab","start_pos":148,"type":"NE_DRUG"}]},"id":0,"instance":"Subsequently, eligible patients who have not experienced disease progression at week 24 will continue in a maintenance phase where a single dose of ipilimumab will be administered once every 12 weeks until disease progression."}
# {"SageMakerOutput":{"ner":[{"end_pos":59,"key":"IBI306","start_pos":53,"type":"NE_DRUG"}]},"id":1,"instance":"The investigational new drug （ IND ） application for IBI306 was approved by the National Medical Products Administration (NMPA) in September 2017."}
# {"SageMakerOutput":{"ner":[{"end_pos":123,"key":"CIMZIATM","start_pos":115,"type":"NE_DRUG"}]},"id":2,"instance":"In June 2005, UCB announced significant positive results for the two pivotal phase III trials (PRECiSE 1 and 2) of CIMZIATM in the induction and maintenance of clinical response in moderate to severe active Crohn's disease."}
# {"SageMakerOutput":{"ner":[{"end_pos":63,"key":"OTEZLA","start_pos":57,"type":"NE_DRUG"},{"end_pos":197,"key":"OTEZLA","start_pos":191,"type":"NE_DRUG"}]},"id":3,"instance":"Carefully weigh the risks and benefits of treatment with OTEZLA for patients with a history of depression and/or suicidal thoughts/behavior, or in patients who develop such symptoms while on OTEZLA."}
# {"SageMakerOutput":{"ner":[{"end_pos":53,"key":"PRTX-100","start_pos":45,"type":"NE_DRUG"}]},"id":4,"instance":"In contrast, pre-clinical data indicate that PRTX-100 may have the potential to treat ITP by reducing the immune-mediated destruction of the platelets through immunomodulatory processes that don ’ t lead to immunosuppression."}

# %% [markdown]
# # Cleanup

# %%
ner_predictor.delete_endpoint()
ner_predictor.delete_model()

# %% [markdown]
# Finally, if the AWS Marketplace subscription was created just for an experiment and you would like to unsubscribe, here are the steps that can be followed. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe from the product on AWS Marketplace:**
#
# Navigate to Machine Learning tab on Your [Software subscriptions page](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=lbr_tab_ml).
# Locate the listing that you would need to cancel, and click Cancel Subscription.
